# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="llama3.2:latest")

# %%
response = llm.invoke([
{"role": "system", "content": "You are a helpful assistant. The output should be in Markdown"},
{"role": "user", "content": "C'est quoi un Agent AI"}
])

# %%
from IPython.display import display, Markdown

# %%
print(display(Markdown(response.content)))
# Out:
# **Définition d'un Agent AI**
#
# Un **Agent AI (Intelligence Artificielle)** est une entité informatique capable de prendre des décisions et d'agir dans un environnement donné, en fonction d'un système de règles et de stratégies. Les agents AI sont conçus pour résoudre des problèmes complexes et interactuer avec leur environnement de manière autonome.
#
# **Caractéristiques des Agents AI**
#
# Voici quelques-unes des caractéristiques clés des agents AI :
#
# * **Connaissance de l'environnement**: les agents AI ont accès à des informations sur leur environnement, qui peuvent être utilisées pour prendre des décisions.
# * **Objectifs et priorités**: chaque agent AI a des objectifs et des priorités définies, qui déterminent son comportement dans le cadre du problème à résoudre.
# * **Décision-making**: les agents AI prennent des décisions en fonction de leurs connaissances, de leur expertise et de leurs objectifs.
# * **Interaction avec l'environnement**: les agents AI peuvent interagir avec leur environnement pour collecter des informations, prendre des actions ou modifier leur comportement.
#
# **Types d'Agents AI**
#
# Il existe plusieurs types d'agents AI, notamment :
#
# * **Agent simple**: un agent qui fonctionne en fonction d'une règle ou d'un algorithme fixe.
# * **Agent stratégique**: un agent qui utilise des stratégies pour résoudre des problèmes complexes et interactuer avec son environnement.
# * **Agent autonome**: un agent qui peut prendre des décisions et agir sans nécessiter de supervision humaine.
#
# **Exemples d'Agents AI**
#
# Voici quelques exemples d'agents AI :
#
# * **Chatbots**: les chatbots sont des agents AI conçus pour simuler une conversation avec un utilisateur.
# * **Automeilleurs**: les automeilleurs sont des agents AI qui aident les humains à résoudre des problèmes tels que la conduite ou le gestion de projet.
# * **Robots**: les robots sont des agents AI conçus pour effectuer des tâches physiques et interactuer avec leur environnement.
#
# En résumé, un agent AI est une entité informatique autonome capable de prendre des décisions et d'agir dans un environnement donné, en fonction d'un système de règles et de stratégies. Les agents AI sont utilisés pour résoudre des problèmes complexes et interactuer avec leur environnement de manière efficace.
# None
