# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from IPython.display import Image, Markdown, display
import base64
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
path = "rag.png"
Image(path)

# %%
Image(path)

# %%
def encode_image(image_path):
      with open(image_path, "rb") as image_file:
          return base64.b64encode(image_file.read()).decode("utf-8")

# %%
img = encode_image(path)

# %%
llm5 = ChatGroq(model="meta-llama/llama-4-scout-17b-16e-instruct")

# %%
resp5 = llm5.invoke(input=[
      HumanMessage(content=[
          {"type": "text", "text": "Qu'est ce que tu vois dans cette image"},
          {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img}"}},
      ])
  ])

# %%
display(Markdown(resp5.content))
# Out:
# L'image représente un processus en quatre étapes qui semble lié au traitement de l'information et à la génération de réponses enrichies en utilisant des modèles de langage avancés. Voici une description détaillée de ce que l'on peut voir :
#
# ### 1. **Requête Utilisateur**
# - **Description** : La première étape montre un utilisateur posant une question. Cela est représenté par une icône de personne avec un nuage de dialogue contenant le mot "QUESTION". L'utilisateur interagit avec un bouton de recherche marqué "QUESTION".
# - **Fonction** : L'utilisateur initie le processus en soumettant une requête ou une question.
#
# ### 2. **Recherche & Récupération (Retrieval)**
# - **Description** : Cette étape est divisée en deux sous-processus principaux :
#   - **Base de Connaissances Externe & Indexation & Embedding** :
#     - Une base de données externe est utilisée pour stocker des informations.
#     - L'indexation et l'embedding sont des processus qui permettent de transformer les données textuelles en vecteurs pour une recherche efficace.
#   - **Moteur de Recherche** :
#     - Utilise la requête de l'utilisateur pour effectuer une recherche dans la base de connaissances.
#     - Le résultat de la recherche est ensuite utilisé pour récupérer des segments pertinents et du contexte.
#
# ### 3. **Génération (Generation)**
# - **Description** : Cette étape implique un **Modèle de Langage (LLM)** qui utilise les informations récupérées pour générer une réponse.
# - **Fonction** :
#   - Le modèle de langage traite la requête de l'utilisateur et les informations récupérées pour produire une réponse enrichie.
#
# ### 4. **Réponse Enrichie**
# - **Description** : La réponse finale générée par le modèle de langage est présentée à l'utilisateur.
# - **Fonction** : Le résultat du processus est une réponse enrichie qui combine les connaissances récupérées avec la compréhension du contexte de la requête.
#
# ### Processus Global
# Le processus peut être résumé comme suit :
# 1. L'utilisateur pose une question.
# 2. La requête est utilisée pour rechercher et récupérer des informations pertinentes à partir d'une base de connaissances externe.
# 3. Les informations récupérées sont utilisées par un modèle de langage pour générer une réponse enrichie.
# 4. La réponse finale est présentée à l'utilisateur.
#
# Ce schéma illustre comment les modèles de langage peuvent être utilisés pour fournir des réponses intelligentes et informées en exploitant des bases de connaissances externes.
