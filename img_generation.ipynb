# %%
from IPython.display import Image

# %%
import urllib.parse

# %%
prompt = urllib.parse.quote("Une chat qui code du Java, style cartoon")

# %%
Image(url=f"https://image.pollinations.ai/prompt/{prompt}")
# Out:
# <img src="https://image.pollinations.ai/prompt/Une%20chat%20qui%20code%20du%20Java%2C%20style%20cartoon"/>
