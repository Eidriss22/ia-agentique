# %%
from dotenv.ipython import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_groq import ChatGroq

# %%
llm2 = ChatGroq(model="openai/gpt-oss-120b")

# %%
from langchain.messages import SystemMessage, HumanMessage
from IPython.display import display, Markdown

# %%
resp2 = llm2.invoke([
    SystemMessage("You are a helpful assistant. The output should be in Markdown"),
    HumanMessage("C'est quoi un Agent AI")
])

# %%
print(display(Markdown(resp2.content)))
# Out:
# ## Qu’est‑ce qu’un **Agent IA** ?
#
# Un **agent d’intelligence artificielle (IA)** est un système logiciel capable d’interagir avec son environnement, d’interpréter des informations, de prendre des décisions et d’agir de façon autonome ou semi‑autonome pour atteindre des objectifs définis.
#
# ---
#
# ### 1. Définition formelle
# Dans le domaine de l’IA et de la robotique, un agent est souvent décrit comme :
#
# > **Perception → Traitement (raisonnement) → Action**
#
# - **Perception** : l’agent reçoit des données (capteurs, texte, images, sons, API, etc.).
# - **Traitement** : il applique des algorithmes (apprentissage automatique, logique, planification, etc.) pour comprendre la situation.
# - **Action** : il génère une réponse ou un comportement (mouvement, texte, commande, etc.) qui influence l’environnement.
#
# ---
#
# ### 2. Types d’agents IA
#
# | Type d’agent | Principales caractéristiques | Exemples concrets |
# |--------------|------------------------------|-------------------|
# | **Agent réactif** | Réagit directement à l’état actuel, sans mémoire du passé. | Systèmes de contrôle de trafic, filtres anti‑spam. |
# | **Agent à base de modèle** | Construit un modèle interne du monde (cartographie, prévisions). | Robots de navigation autonome, assistants vocaux qui comprennent le contexte. |
# | **Agent de planification** | Génère des séquences d’actions pour atteindre un but à long terme. | Systèmes de planification logistique, IA de jeu d’échecs. |
# | **Agent d’apprentissage (agent RL)** | Apprend par essais‑erreurs (reinforcement learning). | Agents de jeux vidéo, robots qui apprennent à marcher. |
# | **Agent conversationnel** | Traite le langage naturel pour dialoguer avec les humains. | ChatGPT, Alexa, Google Assistant. |
# | **Agent multi‑agents** | Plusieurs agents interagissent, coopèrent ou compétitionnent. | Systèmes de marché automatisés, simulations sociales. |
#
# ---
#
# ### 3. Composants clés d’un agent IA
#
# | Composant | Rôle | Technologies fréquentes |
# |-----------|------|--------------------------|
# | **Capteurs / Entrées** | Collecte de données brutes (texte, audio, vidéo, capteurs physiques). | Microphones, caméras, API web, bases de données. |
# | **Modèle de perception** | Transforme les données brutes en informations utiles. | CNN pour images, RNN/Transformer pour texte, reconnaissance vocale. |
# | **Moteur de décision** | Choisit l’action la plus appropriée. | Algorithmes de planification, réseaux de décision, Q‑learning, policies de RL. |
# | **Moteur d’action / Effecteurs** | Exécute la décision (texte, mouvement, commande). | Génération de texte, contrôleurs de moteurs, appels d’API. |
# | **Mémoire / Historique** | Stocke le contexte, les expériences passées. | Bases de données, réseaux de neurones récurrents, systèmes de rappel. |
# | **Feedback / Apprentissage** | Ajuste le comportement à partir des résultats obtenus. | Supervision humaine, récompenses RL, mise à jour de poids de modèle. |
#
# ---
#
# ### 4. Exemple concret : un assistant vocal
#
# 1. **Perception** : le microphone capte la voix → le signal est transformé en texte (ASR).
# 2. **Traitement** : le texte est analysé (NLP) pour identifier l’intention (« mettre le thermostat à 22 °C »).
# 3. **Planification** : l’agent décide de la commande à envoyer au thermostat.
# 4. **Action** : il envoie la requête via une API au dispositif IoT.
# 5. **Feedback** : le thermostat confirme le réglage → l’assistant informe l’utilisateur (« Thermostat réglé à 22 °C »).
#
# ---
#
# ### 5. Pourquoi parler d’« agent » ?
#
# - **Autonomie** : l’agent peut fonctionner sans supervision continue.
# - **Adaptabilité** : il peut s’ajuster à de nouvelles situations grâce à l’apprentissage.
# - **Interaction** : il agit dans un environnement dynamique (physique ou numérique).
#
# Ces propriétés le distinguent d’un simple **programme** qui exécute toujours la même séquence d’instructions.
#
# ---
#
# ### 6. Enjeux et limites
#
# | Enjeu | Description |
# |-------|-------------|
# | **Éthique & responsabilité** | Qui est responsable des actions d’un agent (ex. accidents de voitures autonomes) ? |
# | **Transparence** | Les décisions doivent être explicables (XAI) pour gagner la confiance. |
# | **Robustesse** | L’agent doit résister aux données bruitées, aux attaques adversariales. |
# | **Biais** | Les modèles d’apprentissage peuvent reproduire ou amplifier des biais présents dans les données d’entraînement. |
#
# ---
#
# ### 7. Ressources pour aller plus loin
#
# - **Livres** : *Artificial Intelligence: A Modern Approach* (Russell & Norvig) – chapitres sur les agents.
# - **Cours en ligne** : Coursera – *AI for Everyone* (Andrew Ng) ; edX – *Multi‑Agent Systems*.
# - **Frameworks** : OpenAI Gym (RL), ROS (robotique), Rasa (chatbots), TensorFlow / PyTorch (modèles de perception).
#
# ---
#
# ## En résumé
#
# Un **agent IA** est un système capable de **percevoir**, **raisonner** et **agir** de façon autonome pour atteindre des objectifs. Il combine des techniques de perception (vision, parole, texte), de prise de décision (planification, apprentissage) et d’interaction avec le monde (action, feedback). Les agents sont à la base de nombreuses applications modernes, des assistants vocaux aux véhicules autonomes, en passant par les jeux vidéo et les systèmes de recommandation.
#
# ---
#
# *Vous avez d’autres questions ? N’hésitez pas à préciser le type d’agent qui vous intéresse ou le domaine d’application !*
# None
